# %%
import pandas as pd

# %% [markdown]
# ## Series Any Column

# %%
s1 = pd.Series([10,20,30])
s2 = pd.Series({"A":"Jayant","B":21,})

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s2
# Out:
# A    Jayant
# B        21
# dtype: object

# %% [markdown]
# ## Data Frame

# %%
d1 = pd.DataFrame([1,2,3,4],columns=["Number"])
d2 = pd.DataFrame({
  "Age":[23,45,67],
  "Sallary":[2000,4999,5999],
})

# %%
d1
# Out:
#    Number
# 0       1
# 1       2
# 2       3
# 3       4

# %%
d2
# Out:
#    Age  Sallary
# 0   23     2000
# 1   45     4999
# 2   67     5999

# %%
s1 = pd.Series([10,20,30])
s2 = pd.Series([20,40,60])

# %%
df = pd.DataFrame({"c1":s1,"c2":s2})
df
# Out:
#    c1  c2
# 0  10  20
# 1  20  40
# 2  30  60
