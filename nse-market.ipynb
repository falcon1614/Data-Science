# %%
# !pip install nselib

# !pip install nselib --upgrade
! pip install ydata-profiling
# !pip install --upgrade pip
# https://github.com/RuchiTanmay/nselib/tree/main

# %%
import nselib
from nselib import capital_market

# %%
holly_Day = nselib.trading_holiday_calendar()

# %%
holly_Day.head()
# Out:
#            Product  tradingDate   weekDay  \
# 0  Corporate Bonds  15-Jan-2026  Thursday
# 1  Corporate Bonds  26-Jan-2026    Monday
# 2  Corporate Bonds  15-Feb-2026    Sunday
# 3  Corporate Bonds  03-Mar-2026   Tuesday
# 4  Corporate Bonds  21-Mar-2026  Saturday
#
#                                     description Sr_no morning_session  \
# 0  Municipal Corporation Election - Maharashtra     1            None
# 1                                  Republic Day     2            None
# 2                                 Mahashivratri     3            None
# 3                                          Holi     4            None
# 4                      Id-Ul-Fitr (Ramadan Eid)     5            None
#
#   evening_session
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None

# %%
Block_deals = capital_market.block_deals_data(period="1M")

# %%
Bulk_deal = capital_market.bulk_deal_data(period="1M")

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(Bulk_deal, title="My Profiling Report")
prof.to_file(output_file="Bulk_deal.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 8/8 [00:00<00:00, 469.00it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df = capital_market.short_selling_data(period="1W")

# %%
import pandas as pd

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#           Date      Symbol               SecurityName Quantity
# 0  29-JAN-2026         ABB                   ABB LTD.       41
# 1  29-JAN-2026  ADANIENSOL  ADANI ENERGY SOLUTION LTD       66
# 2  29-JAN-2026    ADANIENT  ADANI ENTERPRISES LIMITED        3
# 3  29-JAN-2026  ADANIGREEN     ADANI GREEN ENERGY LTD      192
# 4  29-JAN-2026    ANGELONE              ANGEL ONE LTD        7
