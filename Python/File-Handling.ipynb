# %% [markdown]
# # File Handling in Python
#
# **File handling refers to the process of performing operations on a file, such as creating, opening, reading, writing and closing it through a programming interface. It involves managing the data flow between the program and the file system on the storage device, ensuring that data is handled safely and efficiently.**
#
# ### Why do we need File Handling
# - To store data permanently, even after the program ends.
# - To access external files like .txt, .csv, .json, etc.
# - To process large files efficiently without using much memory.
# - To automate tasks like reading configs or saving outputs.

# %% [markdown]
# ## Opening a File
#
# ` file = open('filename.txt', 'mode')`

# %%
file = open("file.txt","r")
print(file)
# Out:
# <_io.TextIOWrapper name='file.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# ## Closing a File

# %%
file = open("file.txt","r")
file.close()

# %% [markdown]
# ## Checking File Properties

# %%
file = open("file.txt","r")
print("File Name : ",file.name)
print("File Mode : ", file.mode)
print("Is Close", file.close)

file.close()
print("File Close",file.close)
# Out:
# File Name :  file.txt
# File Mode :  r
# Is Close <built-in method close of _io.TextIOWrapper object at 0x7f0e020ab5a0>
# File Close <built-in method close of _io.TextIOWrapper object at 0x7f0e020ab5a0>

# %% [markdown]
# ## Reading a File

# %%
file = open("file.txt","r")
content = file.read()
print(content)
file.close()
# Out:
# College

# %% [markdown]
# ## Writing a File

# %%
file = open("file.txt","w")
file.write("College")
# Out:
# 7

# %% [markdown]
# ## Using with Statement

# %%
with open("file.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# College

# %% [markdown]
# ## Handling Exceptions When Closing a File

# %%
try:
    file = open("file.txt", "r")
    content = file.read()
    print(content)
finally:
    file.close()
# Out:
# College
