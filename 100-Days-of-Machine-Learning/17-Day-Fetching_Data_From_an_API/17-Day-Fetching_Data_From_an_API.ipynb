# %%
import pandas as pd
import requests

# %%
response = requests.get(r'url=')

# %%
pd.DataFrame(response.json()['results'])[['id','title','overview','realse_data','popularity','vote_avarage','vote_count']]
