# %% [markdown]
# ### LinePlot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(pd.read_csv(r"/run/media/falcon/Local/Data-Science/sort.csv"))

# %%
df = df[df['Quantity'] > 1000].head(20)

# %%
df
# Out:
#            Date      Symbol                   SecurityName  Quantity
# 1   05-FEB-2026   ABCAPITAL   ADITYA BIRLA CAPITAL LIMITED      9530
# 4   05-FEB-2026    ADANIENT      ADANI ENTERPRISES LIMITED      1855
# 5   05-FEB-2026  ADANIGREEN         ADANI GREEN ENERGY LTD      1057
# 12  05-FEB-2026    ASHOKLEY              ASHOK LEYLAND LTD    166974
# 14  05-FEB-2026      AUBANK  AU SMALL FINANCE BANK LIMITED      6265
# 16  05-FEB-2026    AXISBANK              AXIS BANK LIMITED      3425
# 19  05-FEB-2026  BAJAJFINSV          BAJAJ FINSERV LIMITED      1108
# 20  05-FEB-2026  BAJFINANCE          BAJAJ FINANCE LIMITED      2619
# 21  05-FEB-2026  BANDHANBNK           BANDHAN BANK LIMITED     13675
# 23  05-FEB-2026   BANKINDIA                  BANK OF INDIA      4831
# 25  05-FEB-2026         BEL         BHARAT ELECTRONICS LTD      8925
# 28  05-FEB-2026      BIOCON                BIOCON LIMITED.      1845

# %%
df.shape
# Out:
# (12, 4)

# %%
plt.plot(df['Quantity'], df['SecurityName'])
plt.show()

# %%
sns.lineplot(x=df['Symbol'],y=df['Quantity'],data=df)
# Out:
# <Axes: xlabel='Symbol', ylabel='Quantity'>
