# %% [markdown]
# ### LinePlot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(pd.read_csv(r"/run/media/falcon/Local/Data-Science/sort.csv"))

# %%
df = df[df['Quantity'] > 100].head(5)

# %%
df
# Out:
#           Date      Symbol                  SecurityName  Quantity
# 1  05-FEB-2026   ABCAPITAL  ADITYA BIRLA CAPITAL LIMITED      9530
# 2  05-FEB-2026         ACC                   ACC LIMITED       320
# 4  05-FEB-2026    ADANIENT     ADANI ENTERPRISES LIMITED      1855
# 5  05-FEB-2026  ADANIGREEN        ADANI GREEN ENERGY LTD      1057
# 6  05-FEB-2026  ADANIPORTS          ADANI PORT & SEZ LTD       114

# %%
df.shape
# Out:
# (5, 4)

# %%
plt.plot(df['Symbol'], df['SecurityName'])
plt.show()

# %%
sns.lineplot(x=df['Date'],y=df['Symbol'],data=df)
# Out:
# <Axes: xlabel='Date', ylabel='Symbol'>
